# %% [markdown]
# Importando as bibliotecas

# %%
from textblob import TextBlob
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Importando o banco

# %%
dados = pd.read_csv("Banco de dados melhorados1.csv", delimiter=";")

# %% [markdown]
# Atribuindo valores numericos aos rotulos

# %%
def polaridade(pol):
    if pol == 'Positivo':
        return 1.0
    elif pol == 'Neutro':
        return 0.0
    else:
        return -1.0

# %% [markdown]
# Atribuindo ao Dataframe as colunas com os seus repectivos valores

# %%
polaridades = [polaridade(dados["Polaridade"][ind]) for ind in dados.index]

# %% [markdown]
# A coluna "Nvpolaridade" foi atribuida por nos com a finalidade de aproximar ainda mais o rotulo com o sentimento da frase.

# %%
Nvpolaridades = [polaridade(dados["Nvpolaridade"][ind]) for ind in dados.index]

# %%
dados["Polaridade"] = polaridades

# %%
dados["Nvpolaridade"] = Nvpolaridades

# %% [markdown]
# Aplicando a biblioteca TextBlod. As frases de entrada são traduzidas do portugues para o ingles para que o TextBlod execute corretamente

# %%
def polaridade_textblob(text):
    frase = TextBlob (text)
    traduz = TextBlob(str(frase.translate(to="en" )))
    return traduz.polarity

# %%
polaridades = [polaridade_textblob(dados['Frase'][ind]) for ind in dados.index]

# %%
dados['Analise'] = polaridades

# %% [markdown]
# Analisando o Dataframe

# %%
dados
# Out:
#                                                 Frase  Polaridade  \
# 0   Poderia ter sido melhor devido ao pouco tempo ...         1.0
# 1   Me sai bem na avaliação pois ele desenvolveu o...         1.0
# 2   Foi um desenvolvimento mediano poderia ter um ...         0.0
# 3   Poderia ser melhor pois não me doei o suficien...         0.0
# 4            Tive um desempenho razoavel na avaliação         1.0
# 5   O professor não mostrou uma completa dominio n...         1.0
# 6                De acordo com o professor eu fui bem         1.0
# 7   Me sinto frustrado com algumas materias por nã...         0.0
# 8                     Ocorreu de maneira satisfatoria         1.0
# 9   Aula bastante prudutiva pois foi abordado dive...         1.0
# 10  Diante das grandes dificudades acredito que te...         1.0
# 11                             Muito bom o desempenho         1.0
# 12  Hoje eu não prestei muita atençao no conteudo ...         0.0
# 13  Desempenho mediano apresentado dificuldades sa...        -1.0
# 14  Gostei do meu desempenho essa é uma materia qu...         1.0
# 15  Eu acredito que fui bem na avaliação pois me p...         1.0
# 16  Desempenho moderado devido ao cansaço que é ap...         0.0
# 17  Na avaliação de libras obtive um bom desempenh...         1.0
# 18  Achei que poderia ter sido melhor mais pela fa...         0.0
# 19  Fui otimo na avaliação de libras minha dificud...         1.0
# 20  Nesta avaliação tive um otimo desempenho apren...         1.0
# 21   Fui bem estaria bem confiante quanto ao conteudo         1.0
# 22  Tenho muita coisa para melhorar mais desde o i...         0.0
# 23                                   Não satisfatorio         0.0
# 24  Pela a avaliação ser de consulta facilitou bas...         1.0
# 25                   Mediocre poderia ter sido melhor         0.0
# 26  Eu acho que fui muito bem pois o professor me ...         1.0
# 27   Não estava preprado para realizar esta atividade         0.0
# 28                           Meu desempenho foi otimo         1.0
# 29  Por eu ter feito um estagio na area o assunto ...         1.0
# 30  Algoritmo e um da materias mais intensas do cu...         0.0
# 31  A avaliação aplicada estava de acordo com o co...         1.0
# 32  Foi uma avaliação que tratou de varios pontos ...         1.0
# 33  não fui dos melhores faltou um pouco de conhec...         0.0
# 34         Bom desempenho estudando fica melhor ainda         0.0
# 35                                     Bom desempenho         1.0
# 36  Neutro prestando atenção fazendo pesquisas par...         1.0
# 37  Não muito bem esperava que seria diferente o m...         0.0
# 38  Decepcionada por não conseguir tirar uma nota boa         0.0
# 39  Eu perdi algumas aulas estou um pouco receioso...         0.0
# 40                        Meu desempenho e muito ruim         0.0
# 41                                   Não satisfatorio        -1.0
# 42  Bem o ato de conseguir evoluir a cada dia em f...         1.0
# 43  Desempenho bom porem e necessario mudar e melh...         1.0
# 44  Achei muito bom meu desempenho pois consegui a...         1.0
#
#     Nvpolaridade   Analise
# 0            0.0  0.062500
# 1            1.0  0.100000
# 2            0.0  0.061111
# 3           -1.0  0.250000
# 4            0.0  0.200000
# 5           -1.0 -0.051667
# 6            1.0  0.000000
# 7           -1.0 -0.700000
# 8            1.0  0.000000
# 9            0.0  0.100000
# 10           1.0  0.900000
# 11           1.0  0.910000
# 12          -1.0  0.093750
# 13          -1.0 -0.158333
# 14           1.0  0.341667
# 15           1.0  0.000000
# 16          -1.0 -0.041667
# 17           1.0  0.550000
# 18          -1.0  0.187500
# 19           1.0  0.455000
# 20           1.0  0.600000
# 21           1.0  0.650000
# 22           1.0  0.166667
# 23          -1.0  0.000000
# 24           1.0  0.000000
# 25           0.0  0.000000
# 26           1.0  0.200000
# 27          -1.0  0.000000
# 28           1.0  0.800000
# 29           1.0  0.273016
# 30          -1.0 -0.125000
# 31           1.0  0.000000
# 32           1.0  0.091667
# 33          -1.0  0.406250
# 34           1.0  0.600000
# 35           1.0  0.700000
# 36           0.0  0.500000
# 37          -1.0  0.100000
# 38          -1.0 -0.025000
# 39           0.0 -0.393750
# 40          -1.0 -0.910000
# 41          -1.0  0.000000
# 42           1.0  0.250000
# 43           1.0  0.233333
# 44           1.0  0.327500

# %% [markdown]
# Função para tranformar os numeros flutuantes em numeros inteiros de acordo com o seus valores de polaridade

# %%
def predicao(anls):
    if anls >= 0.1:
        return 1.0
    elif (anls <= 0.1) and (anls >= -0.1):
        return 0.0
    else:
        return -1.0

# %% [markdown]
# Função para comparar o valor do rotulo com o valor da polaridade da frase

# %%
def acuracia(anls, pred):
    if (anls - pred) == 0:
        return 'certo'
    else:
        return 'errado'

# %% [markdown]
# Aplicando a função "predicao" na coluna "Analise"

# %%
predicao = [predicao(dados['Analise'][ind]) for ind in dados.index]

# %% [markdown]
# Atribuindo uma nova coluna com o valor inteiro retornado pela funcão "predicao"

# %%
dados["Predicao"] = predicao

# %% [markdown]
# Aplicando a funcão de comparação entre as colunas "Nvpolaridade" e "Predicao"

# %%
acuracia = [acuracia(dados['Nvpolaridade'][ind], dados['Predicao'][ind]) for ind in dados.index]

# %%
dados["Acuracia"] = acuracia

# %% [markdown]
# Analisando o Dataframe

# %%
dados
# Out:
#                                                 Frase  Polaridade  \
# 0   Poderia ter sido melhor devido ao pouco tempo ...         1.0
# 1   Me sai bem na avaliação pois ele desenvolveu o...         1.0
# 2   Foi um desenvolvimento mediano poderia ter um ...         0.0
# 3   Poderia ser melhor pois não me doei o suficien...         0.0
# 4            Tive um desempenho razoavel na avaliação         1.0
# 5   O professor não mostrou uma completa dominio n...         1.0
# 6                De acordo com o professor eu fui bem         1.0
# 7   Me sinto frustrado com algumas materias por nã...         0.0
# 8                     Ocorreu de maneira satisfatoria         1.0
# 9   Aula bastante prudutiva pois foi abordado dive...         1.0
# 10  Diante das grandes dificudades acredito que te...         1.0
# 11                             Muito bom o desempenho         1.0
# 12  Hoje eu não prestei muita atençao no conteudo ...         0.0
# 13  Desempenho mediano apresentado dificuldades sa...        -1.0
# 14  Gostei do meu desempenho essa é uma materia qu...         1.0
# 15  Eu acredito que fui bem na avaliação pois me p...         1.0
# 16  Desempenho moderado devido ao cansaço que é ap...         0.0
# 17  Na avaliação de libras obtive um bom desempenh...         1.0
# 18  Achei que poderia ter sido melhor mais pela fa...         0.0
# 19  Fui otimo na avaliação de libras minha dificud...         1.0
# 20  Nesta avaliação tive um otimo desempenho apren...         1.0
# 21   Fui bem estaria bem confiante quanto ao conteudo         1.0
# 22  Tenho muita coisa para melhorar mais desde o i...         0.0
# 23                                   Não satisfatorio         0.0
# 24  Pela a avaliação ser de consulta facilitou bas...         1.0
# 25                   Mediocre poderia ter sido melhor         0.0
# 26  Eu acho que fui muito bem pois o professor me ...         1.0
# 27   Não estava preprado para realizar esta atividade         0.0
# 28                           Meu desempenho foi otimo         1.0
# 29  Por eu ter feito um estagio na area o assunto ...         1.0
# 30  Algoritmo e um da materias mais intensas do cu...         0.0
# 31  A avaliação aplicada estava de acordo com o co...         1.0
# 32  Foi uma avaliação que tratou de varios pontos ...         1.0
# 33  não fui dos melhores faltou um pouco de conhec...         0.0
# 34         Bom desempenho estudando fica melhor ainda         0.0
# 35                                     Bom desempenho         1.0
# 36  Neutro prestando atenção fazendo pesquisas par...         1.0
# 37  Não muito bem esperava que seria diferente o m...         0.0
# 38  Decepcionada por não conseguir tirar uma nota boa         0.0
# 39  Eu perdi algumas aulas estou um pouco receioso...         0.0
# 40                        Meu desempenho e muito ruim         0.0
# 41                                   Não satisfatorio        -1.0
# 42  Bem o ato de conseguir evoluir a cada dia em f...         1.0
# 43  Desempenho bom porem e necessario mudar e melh...         1.0
# 44  Achei muito bom meu desempenho pois consegui a...         1.0
#
#     Nvpolaridade   Analise  Predicao Acuracia
# 0            0.0  0.062500       0.0    certo
# 1            1.0  0.100000       1.0    certo
# 2            0.0  0.061111       0.0    certo
# 3           -1.0  0.250000       1.0   errado
# 4            0.0  0.200000       1.0   errado
# 5           -1.0 -0.051667       0.0   errado
# 6            1.0  0.000000       0.0   errado
# 7           -1.0 -0.700000      -1.0    certo
# 8            1.0  0.000000       0.0   errado
# 9            0.0  0.100000       1.0   errado
# 10           1.0  0.900000       1.0    certo
# 11           1.0  0.910000       1.0    certo
# 12          -1.0  0.093750       0.0   errado
# 13          -1.0 -0.158333      -1.0    certo
# 14           1.0  0.341667       1.0    certo
# 15           1.0  0.000000       0.0   errado
# 16          -1.0 -0.041667       0.0   errado
# 17           1.0  0.550000       1.0    certo
# 18          -1.0  0.187500       1.0   errado
# 19           1.0  0.455000       1.0    certo
# 20           1.0  0.600000       1.0    certo
# 21           1.0  0.650000       1.0    certo
# 22           1.0  0.166667       1.0    certo
# 23          -1.0  0.000000       0.0   errado
# 24           1.0  0.000000       0.0   errado
# 25           0.0  0.000000       0.0    certo
# 26           1.0  0.200000       1.0    certo
# 27          -1.0  0.000000       0.0   errado
# 28           1.0  0.800000       1.0    certo
# 29           1.0  0.273016       1.0    certo
# 30          -1.0 -0.125000      -1.0    certo
# 31           1.0  0.000000       0.0   errado
# 32           1.0  0.091667       0.0   errado
# 33          -1.0  0.406250       1.0   errado
# 34           1.0  0.600000       1.0    certo
# 35           1.0  0.700000       1.0    certo
# 36           0.0  0.500000       1.0   errado
# 37          -1.0  0.100000       1.0   errado
# 38          -1.0 -0.025000       0.0   errado
# 39           0.0 -0.393750      -1.0   errado
# 40          -1.0 -0.910000      -1.0    certo
# 41          -1.0  0.000000       0.0   errado
# 42           1.0  0.250000       1.0    certo
# 43           1.0  0.233333       1.0    certo
# 44           1.0  0.327500       1.0    certo

# %% [markdown]
# Indice de acertos

# %%
dados["Acuracia"].value_counts()
# Out:
# certo     24
# errado    21
# Name: Acuracia, dtype: int64

# %%
x = dados["Acuracia"].value_counts()
labels_list = ['Certo', 'Errado']
plt.axis('equal')
ex=(0.1,0.1)
plt.pie(x, labels=labels_list, autopct='%1.1f%%', explode=ex, shadow=True)
plt.title('Analise')
plt.show()
