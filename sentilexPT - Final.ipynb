# %% [markdown]
# Importando as Bibliotecas

# %%
import nltk
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Importando o Léxico

# %%
sentilexpt = open('SentiLex-lem-PT-melhorado.txt','r', encoding = 'utf-8')

# %% [markdown]
# Iterar sobre o Léxico

# %%
dic_palavra_polaridade = {}
for i in sentilexpt.readlines():
    pos_ponto = i.find('.')
    palavra = (i[:pos_ponto])
    pol_pos = i.find('POL')
    polaridade = (i[pol_pos+4:pol_pos+6]).replace(';',' ')
    dic_palavra_polaridade[palavra] = polaridade

# %% [markdown]
# Atribuindo valores a cada palavra de acordo com o Sentilex na frase de entrada e retornar o valor final da frase completa atraves do operador somatorio (sum)

# %%
def Score_sentimento(frase):
    frase = frase.lower()
    l_sentimento = []
    for p in frase.split():
        l_sentimento.append(int(dic_palavra_polaridade.get(p, 0)))
    score = sum(l_sentimento)
    return '{}'.format(score)

# %% [markdown]
# Lendo o arquivo banco de dados. A coluna "Polaridade" foi o rotulo de sentimento atribuido pelo aluno. A coluna "Nvpolaridade" foi atribuida por nos com a finalidade de aproximar ainda mais o rotulo com o sentimento da frase.

# %%
dados = pd.read_csv("Banco de dados melhorados1.csv", delimiter=";")

# %% [markdown]
# Aplicando a função Score_sentimento e colocando no Dataframe uma coluna "Sentimento" com o valor da frase inteira

# %%
sentimento = [Score_sentimento(dados["Frase"][ind]) for ind in dados.index]

# %%
dados["Sentimento"] = sentimento

# %%
banco = dados

# %%
banco
# Out:
#                                                 Frase Polaridade Nvpolaridade  \
# 0   Poderia ter sido melhor devido ao pouco tempo ...   Positivo       Neutro
# 1   Me sai bem na avaliação pois ele desenvolveu o...   Positivo     Positivo
# 2   Foi um desenvolvimento mediano poderia ter um ...     Neutro       Neutro
# 3   Poderia ser melhor pois não me doei o suficien...     Neutro     Negativo
# 4            Tive um desempenho razoavel na avaliação   Positivo       Neutro
# 5   O professor não mostrou uma completa dominio n...   Positivo     Negativo
# 6                De acordo com o professor eu fui bem   Positivo     Positivo
# 7   Me sinto frustrado com algumas materias por nã...     Neutro     Negativo
# 8                     Ocorreu de maneira satisfatoria   Positivo     Positivo
# 9   Aula bastante prudutiva pois foi abordado dive...   Positivo       Neutro
# 10  Diante das grandes dificudades acredito que te...   Positivo     Positivo
# 11                             Muito bom o desempenho   Positivo     Positivo
# 12  Hoje eu não prestei muita atençao no conteudo ...     Neutro     Negativo
# 13  Desempenho mediano apresentado dificuldades sa...   Negativo     Negativo
# 14  Gostei do meu desempenho essa é uma materia qu...   Positivo     Positivo
# 15  Eu acredito que fui bem na avaliação pois me p...   Positivo     Positivo
# 16  Desempenho moderado devido ao cansaço que é ap...     Neutro     Negativo
# 17  Na avaliação de libras obtive um bom desempenh...   Positivo     Positivo
# 18  Achei que poderia ter sido melhor mais pela fa...     Neutro     Negativo
# 19  Fui otimo na avaliação de libras minha dificud...   Positivo     Positivo
# 20  Nesta avaliação tive um otimo desempenho apren...   Positivo     Positivo
# 21   Fui bem estaria bem confiante quanto ao conteudo   Positivo     Positivo
# 22  Tenho muita coisa para melhorar mais desde o i...     Neutro     Positivo
# 23                                   Não satisfatorio     Neutro     Negativo
# 24  Pela a avaliação ser de consulta facilitou bas...   Positivo     Positivo
# 25                   Mediocre poderia ter sido melhor     Neutro       Neutro
# 26  Eu acho que fui muito bem pois o professor me ...   Positivo     Positivo
# 27   Não estava preprado para realizar esta atividade     Neutro     Negativo
# 28                           Meu desempenho foi otimo   Positivo     Positivo
# 29  Por eu ter feito um estagio na area o assunto ...   Positivo     Positivo
# 30  Algoritmo e um da materias mais intensas do cu...     Neutro     Negativo
# 31  A avaliação aplicada estava de acordo com o co...   Positivo     Positivo
# 32  Foi uma avaliação que tratou de varios pontos ...   Positivo     Positivo
# 33  não fui dos melhores faltou um pouco de conhec...     Neutro     Negativo
# 34         Bom desempenho estudando fica melhor ainda     Neutro     Positivo
# 35                                     Bom desempenho   Positivo     Positivo
# 36  Neutro prestando atenção fazendo pesquisas par...   Positivo       Neutro
# 37  Não muito bem esperava que seria diferente o m...     Neutro     Negativo
# 38  Decepcionada por não conseguir tirar uma nota boa     Neutro     Negativo
# 39  Eu perdi algumas aulas estou um pouco receioso...     Neutro       Neutro
# 40                        Meu desempenho e muito ruim     Neutro     Negativo
# 41                                   Não satisfatorio   Negativo     Negativo
# 42  Bem o ato de conseguir evoluir a cada dia em f...   Positivo     Positivo
# 43  Desempenho bom porem e necessario mudar e melh...   Positivo     Positivo
# 44  Achei muito bom meu desempenho pois consegui a...   Positivo     Positivo
#
#    Sentimento
# 0           1
# 1           2
# 2           0
# 3           0
# 4           1
# 5           0
# 6           2
# 7          -2
# 8           1
# 9           1
# 10          5
# 11          2
# 12         -6
# 13         -1
# 14          2
# 15          3
# 16         -2
# 17          5
# 18         -1
# 19          3
# 20          3
# 21          5
# 22          4
# 23         -1
# 24          4
# 25          0
# 26          2
# 27         -1
# 28          2
# 29          5
# 30         -2
# 31          0
# 32          2
# 33         -3
# 34          4
# 35          2
# 36          0
# 37          0
# 38         -2
# 39         -3
# 40         -1
# 41         -1
# 42          4
# 43          4
# 44          2

# %% [markdown]
# Classificando as frases de acordo com os seus valores para comparação com os rotulos

# %%
def polaridade_numero(pol):
    if int(pol) <= -1:
        return -1
    elif int(pol) == 0:
        return 0
    else: 
        return 1

# %% [markdown]
# Atribuindo valores numericos ao rotulos para comparar com os valores das frases

# %%
def polaridade_texto(pol):
    if pol == 'Positivo':
        return 1
    elif pol == 'Neutro':
        return 0
    else:
        return -1

# %% [markdown]
# Comparação entre os rotulos e os valores das frases

# %%
def acuracia(anls, pred):
    if (anls - pred) == 0:
        return 0
    else:
        return 1

# %% [markdown]
# Organizando no Dataframe as colunas com os seus respectivos valores

# %%
polaridade = [polaridade_texto(banco['Nvpolaridade'][ind]) for ind in banco.index]

# %%
banco['Nvpolaridade'] = polaridade

# %%
polaridade_num = [polaridade_numero(banco['Sentimento'][ind]) for ind in banco.index]

# %%
banco['Sentimento'] = polaridade_num

# %%
acuracia = [acuracia(banco['Nvpolaridade'][ind], banco['Sentimento'][ind]) for ind in banco.index]

# %%
acuracia = pd.DataFrame(acuracia)

# %%
banco['Acuracia'] = acuracia

# %% [markdown]
# Analisando o banco

# %%
banco
# Out:
#                                                 Frase Polaridade  \
# 0   Poderia ter sido melhor devido ao pouco tempo ...   Positivo
# 1   Me sai bem na avaliação pois ele desenvolveu o...   Positivo
# 2   Foi um desenvolvimento mediano poderia ter um ...     Neutro
# 3   Poderia ser melhor pois não me doei o suficien...     Neutro
# 4            Tive um desempenho razoavel na avaliação   Positivo
# 5   O professor não mostrou uma completa dominio n...   Positivo
# 6                De acordo com o professor eu fui bem   Positivo
# 7   Me sinto frustrado com algumas materias por nã...     Neutro
# 8                     Ocorreu de maneira satisfatoria   Positivo
# 9   Aula bastante prudutiva pois foi abordado dive...   Positivo
# 10  Diante das grandes dificudades acredito que te...   Positivo
# 11                             Muito bom o desempenho   Positivo
# 12  Hoje eu não prestei muita atençao no conteudo ...     Neutro
# 13  Desempenho mediano apresentado dificuldades sa...   Negativo
# 14  Gostei do meu desempenho essa é uma materia qu...   Positivo
# 15  Eu acredito que fui bem na avaliação pois me p...   Positivo
# 16  Desempenho moderado devido ao cansaço que é ap...     Neutro
# 17  Na avaliação de libras obtive um bom desempenh...   Positivo
# 18  Achei que poderia ter sido melhor mais pela fa...     Neutro
# 19  Fui otimo na avaliação de libras minha dificud...   Positivo
# 20  Nesta avaliação tive um otimo desempenho apren...   Positivo
# 21   Fui bem estaria bem confiante quanto ao conteudo   Positivo
# 22  Tenho muita coisa para melhorar mais desde o i...     Neutro
# 23                                   Não satisfatorio     Neutro
# 24  Pela a avaliação ser de consulta facilitou bas...   Positivo
# 25                   Mediocre poderia ter sido melhor     Neutro
# 26  Eu acho que fui muito bem pois o professor me ...   Positivo
# 27   Não estava preprado para realizar esta atividade     Neutro
# 28                           Meu desempenho foi otimo   Positivo
# 29  Por eu ter feito um estagio na area o assunto ...   Positivo
# 30  Algoritmo e um da materias mais intensas do cu...     Neutro
# 31  A avaliação aplicada estava de acordo com o co...   Positivo
# 32  Foi uma avaliação que tratou de varios pontos ...   Positivo
# 33  não fui dos melhores faltou um pouco de conhec...     Neutro
# 34         Bom desempenho estudando fica melhor ainda     Neutro
# 35                                     Bom desempenho   Positivo
# 36  Neutro prestando atenção fazendo pesquisas par...   Positivo
# 37  Não muito bem esperava que seria diferente o m...     Neutro
# 38  Decepcionada por não conseguir tirar uma nota boa     Neutro
# 39  Eu perdi algumas aulas estou um pouco receioso...     Neutro
# 40                        Meu desempenho e muito ruim     Neutro
# 41                                   Não satisfatorio   Negativo
# 42  Bem o ato de conseguir evoluir a cada dia em f...   Positivo
# 43  Desempenho bom porem e necessario mudar e melh...   Positivo
# 44  Achei muito bom meu desempenho pois consegui a...   Positivo
#
#     Nvpolaridade  Sentimento  Acuracia
# 0              0           1         1
# 1              1           1         0
# 2              0           0         0
# 3             -1           0         1
# 4              0           1         1
# 5             -1           0         1
# 6              1           1         0
# 7             -1          -1         0
# 8              1           1         0
# 9              0           1         1
# 10             1           1         0
# 11             1           1         0
# 12            -1          -1         0
# 13            -1          -1         0
# 14             1           1         0
# 15             1           1         0
# 16            -1          -1         0
# 17             1           1         0
# 18            -1          -1         0
# 19             1           1         0
# 20             1           1         0
# 21             1           1         0
# 22             1           1         0
# 23            -1          -1         0
# 24             1           1         0
# 25             0           0         0
# 26             1           1         0
# 27            -1          -1         0
# 28             1           1         0
# 29             1           1         0
# 30            -1          -1         0
# 31             1           0         1
# 32             1           1         0
# 33            -1          -1         0
# 34             1           1         0
# 35             1           1         0
# 36             0           0         0
# 37            -1           0         1
# 38            -1          -1         0
# 39             0          -1         1
# 40            -1          -1         0
# 41            -1          -1         0
# 42             1           1         0
# 43             1           1         0
# 44             1           1         0

# %% [markdown]
# Indice de acertos (0 = certo, 1 = errado).

# %%
acuracia[0].value_counts()
# Out:
# 0    37
# 1     8
# Name: 0, dtype: int64

# %%
dados.hist(column='Acuracia', bins=3)
plt.show()

# %% [markdown]
# Frases com divergencia entre o seu rotulo e o valor

# %%
banco.loc[banco['Acuracia'] == 1]
# Out:
#                                                 Frase Polaridade  \
# 0   Poderia ter sido melhor devido ao pouco tempo ...   Positivo
# 3   Poderia ser melhor pois não me doei o suficien...     Neutro
# 4            Tive um desempenho razoavel na avaliação   Positivo
# 5   O professor não mostrou uma completa dominio n...   Positivo
# 9   Aula bastante prudutiva pois foi abordado dive...   Positivo
# 31  A avaliação aplicada estava de acordo com o co...   Positivo
# 37  Não muito bem esperava que seria diferente o m...     Neutro
# 39  Eu perdi algumas aulas estou um pouco receioso...     Neutro
#
#     Nvpolaridade  Sentimento  Acuracia
# 0              0           1         1
# 3             -1           0         1
# 4              0           1         1
# 5             -1           0         1
# 9              0           1         1
# 31             1           0         1
# 37            -1           0         1
# 39             0          -1         1

# %% [markdown]
# Função para retornar os valores das frases individualmente para analise

# %%
def Score_sentimentotest(frase):
    frase = frase.lower()
    l_sentimento = dict()
    for p in frase.split():
        l_sentimento[p] = int(dic_palavra_polaridade.get(p, 0))
    for i in l_sentimento.items():
        return l_sentimento

# %%
score = [Score_sentimentotest(dados["Frase"][ind]) for ind in dados.index]

# %%
dados["Valores das palavras"] = score

# %% [markdown]
# Analisando

# %%
dados
# Out:
#                                                 Frase Polaridade  \
# 0   Poderia ter sido melhor devido ao pouco tempo ...   Positivo
# 1   Me sai bem na avaliação pois ele desenvolveu o...   Positivo
# 2   Foi um desenvolvimento mediano poderia ter um ...     Neutro
# 3   Poderia ser melhor pois não me doei o suficien...     Neutro
# 4            Tive um desempenho razoavel na avaliação   Positivo
# 5   O professor não mostrou uma completa dominio n...   Positivo
# 6                De acordo com o professor eu fui bem   Positivo
# 7   Me sinto frustrado com algumas materias por nã...     Neutro
# 8                     Ocorreu de maneira satisfatoria   Positivo
# 9   Aula bastante prudutiva pois foi abordado dive...   Positivo
# 10  Diante das grandes dificudades acredito que te...   Positivo
# 11                             Muito bom o desempenho   Positivo
# 12  Hoje eu não prestei muita atençao no conteudo ...     Neutro
# 13  Desempenho mediano apresentado dificuldades sa...   Negativo
# 14  Gostei do meu desempenho essa é uma materia qu...   Positivo
# 15  Eu acredito que fui bem na avaliação pois me p...   Positivo
# 16  Desempenho moderado devido ao cansaço que é ap...     Neutro
# 17  Na avaliação de libras obtive um bom desempenh...   Positivo
# 18  Achei que poderia ter sido melhor mais pela fa...     Neutro
# 19  Fui otimo na avaliação de libras minha dificud...   Positivo
# 20  Nesta avaliação tive um otimo desempenho apren...   Positivo
# 21   Fui bem estaria bem confiante quanto ao conteudo   Positivo
# 22  Tenho muita coisa para melhorar mais desde o i...     Neutro
# 23                                   Não satisfatorio     Neutro
# 24  Pela a avaliação ser de consulta facilitou bas...   Positivo
# 25                   Mediocre poderia ter sido melhor     Neutro
# 26  Eu acho que fui muito bem pois o professor me ...   Positivo
# 27   Não estava preprado para realizar esta atividade     Neutro
# 28                           Meu desempenho foi otimo   Positivo
# 29  Por eu ter feito um estagio na area o assunto ...   Positivo
# 30  Algoritmo e um da materias mais intensas do cu...     Neutro
# 31  A avaliação aplicada estava de acordo com o co...   Positivo
# 32  Foi uma avaliação que tratou de varios pontos ...   Positivo
# 33  não fui dos melhores faltou um pouco de conhec...     Neutro
# 34         Bom desempenho estudando fica melhor ainda     Neutro
# 35                                     Bom desempenho   Positivo
# 36  Neutro prestando atenção fazendo pesquisas par...   Positivo
# 37  Não muito bem esperava que seria diferente o m...     Neutro
# 38  Decepcionada por não conseguir tirar uma nota boa     Neutro
# 39  Eu perdi algumas aulas estou um pouco receioso...     Neutro
# 40                        Meu desempenho e muito ruim     Neutro
# 41                                   Não satisfatorio   Negativo
# 42  Bem o ato de conseguir evoluir a cada dia em f...   Positivo
# 43  Desempenho bom porem e necessario mudar e melh...   Positivo
# 44  Achei muito bom meu desempenho pois consegui a...   Positivo
#
#     Nvpolaridade  Sentimento  Acuracia  \
# 0              0           1         1
# 1              1           1         0
# 2              0           0         0
# 3             -1           0         1
# 4              0           1         1
# 5             -1           0         1
# 6              1           1         0
# 7             -1          -1         0
# 8              1           1         0
# 9              0           1         1
# 10             1           1         0
# 11             1           1         0
# 12            -1          -1         0
# 13            -1          -1         0
# 14             1           1         0
# 15             1           1         0
# 16            -1          -1         0
# 17             1           1         0
# 18            -1          -1         0
# 19             1           1         0
# 20             1           1         0
# 21             1           1         0
# 22             1           1         0
# 23            -1          -1         0
# 24             1           1         0
# 25             0           0         0
# 26             1           1         0
# 27            -1          -1         0
# 28             1           1         0
# 29             1           1         0
# 30            -1          -1         0
# 31             1           0         1
# 32             1           1         0
# 33            -1          -1         0
# 34             1           1         0
# 35             1           1         0
# 36             0           0         0
# 37            -1           0         1
# 38            -1          -1         0
# 39             0          -1         1
# 40            -1          -1         0
# 41            -1          -1         0
# 42             1           1         0
# 43             1           1         0
# 44             1           1         0
#
#                                  Valores das palavras
# 0   {'poderia': -1, 'ter': 0, 'sido': 0, 'melhor':...
# 1   {'me': 0, 'sai': 0, 'bem': 2, 'na': 0, 'avalia...
# 2   {'foi': 0, 'um': 0, 'desenvolvimento': 0, 'med...
# 3   {'poderia': -1, 'ser': 0, 'melhor': 2, 'pois':...
# 4   {'tive': 0, 'um': 0, 'desempenho': 0, 'razoave...
# 5   {'o': 0, 'professor': 0, 'não': -2, 'mostrou':...
# 6   {'de': 0, 'acordo': 0, 'com': 0, 'o': 0, 'prof...
# 7   {'me': 0, 'sinto': 0, 'frustrado': -1, 'com': ...
# 8   {'ocorreu': 0, 'de': 0, 'maneira': 0, 'satisfa...
# 9   {'aula': 0, 'bastante': 1, 'prudutiva': 0, 'po...
# 10  {'diante': 0, 'das': 0, 'grandes': 1, 'dificud...
# 11    {'muito': 0, 'bom': 2, 'o': 0, 'desempenho': 0}
# 12  {'hoje': 0, 'eu': 0, 'não': -2, 'prestei': 1, ...
# 13  {'desempenho': 0, 'mediano': 1, 'apresentado':...
# 14  {'gostei': 1, 'do': 0, 'meu': 0, 'desempenho':...
# 15  {'eu': 0, 'acredito': 0, 'que': 0, 'fui': 0, '...
# 16  {'desempenho': 0, 'moderado': -1, 'devido': 0,...
# 17  {'na': 0, 'avaliação': 0, 'de': 0, 'libras': 0...
# 18  {'achei': 0, 'que': 0, 'poderia': -1, 'ter': 0...
# 19  {'fui': 0, 'otimo': 2, 'na': 0, 'avaliação': 0...
# 20  {'nesta': 0, 'avaliação': 0, 'tive': 0, 'um': ...
# 21  {'fui': 0, 'bem': 2, 'estaria': 0, 'confiante'...
# 22  {'tenho': 0, 'muita': 0, 'coisa': 0, 'para': 0...
# 23                     {'não': -2, 'satisfatorio': 1}
# 24  {'pela': 0, 'a': 0, 'avaliação': 0, 'ser': 0, ...
# 25  {'mediocre': -1, 'poderia': -1, 'ter': 0, 'sid...
# 26  {'eu': 0, 'acho': 0, 'que': 0, 'fui': 0, 'muit...
# 27  {'não': -2, 'estava': 0, 'preprado': 0, 'para'...
# 28  {'meu': 0, 'desempenho': 0, 'foi': 0, 'otimo': 2}
# 29  {'por': 0, 'eu': 0, 'ter': 0, 'feito': 0, 'um'...
# 30  {'algoritmo': 0, 'e': 0, 'um': 0, 'da': 0, 'ma...
# 31  {'a': 0, 'avaliação': 0, 'aplicada': 0, 'estav...
# 32  {'foi': 0, 'uma': 0, 'avaliação': 0, 'que': 0,...
# 33  {'não': -2, 'fui': 0, 'dos': 0, 'melhores': 1,...
# 34  {'bom': 2, 'desempenho': 0, 'estudando': 0, 'f...
# 35                        {'bom': 2, 'desempenho': 0}
# 36  {'neutro': 0, 'prestando': 0, 'atenção': 0, 'f...
# 37  {'não': -2, 'muito': 0, 'bem': 2, 'esperava': ...
# 38  {'decepcionada': -1, 'por': 0, 'não': -2, 'con...
# 39  {'eu': 0, 'perdi': -1, 'algumas': 0, 'aulas': ...
# 40  {'meu': 0, 'desempenho': 0, 'e': 0, 'muito': 0...
# 41                     {'não': -2, 'satisfatorio': 1}
# 42  {'bem': 2, 'o': 0, 'ato': 0, 'de': 0, 'consegu...
# 43  {'desempenho': 0, 'bom': 2, 'porem': 0, 'e': 0...
# 44  {'achei': 0, 'muito': 0, 'bom': 2, 'meu': 0, '...
