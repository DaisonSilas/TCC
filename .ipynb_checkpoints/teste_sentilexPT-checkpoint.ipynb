# %%
import nltk

# %%
import numpy as np

# %%
import pandas as pd

# %%
sentilexpt = open('SentiLex-lem-PT02.txt','r', encoding = 'utf-8')

# %%
dic_palavra_polaridade = {}
for i in sentilexpt.readlines():
    pos_ponto = i.find('.')
    palavra = (i[:pos_ponto])
    pol_pos = i.find('POL')
    polaridade = (i[pol_pos+7:pol_pos+9]).replace(';',' ')
    dic_palavra_polaridade[palavra] = polaridade

# %%
def Score_sentimento(frase):
    frase = frase.lower()
    l_sentimento = []
    for p in frase.split():
        l_sentimento.append(int(dic_palavra_polaridade.get(p, 0)))
    score = sum(l_sentimento)
    if score > 0:
        return 'Score:{}'.format(score)
    elif  score == 0:
        return 'Score:{}'.format(score)
    else:
        return'Score:{}'.format(score)

# %% [markdown]
# Teste

# %%
Score_sentimento('gostei materia')
# Out:
# 'Score:0'

# %%
dados = pd.read_csv("Banco de dados melhorados.csv", delimiter=";")

# %%
sentimento = [Score_sentimento(dados["Frase"][ind]) for ind in dados.index]

# %%
dados["Sentimento"] = sentimento

# %%
dados
# Out:
#                                                 Frase Polaridade Nvpolaridade  \
# 0   Poderia ter sido melhor, devido ao pouco tempo...   Positivo       Neutro
# 1   Me sai bem na avaliação pois ele desenvolveu o...   Positivo     Positivo
# 2   Foi um desenvolvimento mediano, poderia ter um...     Neutro       Neutro
# 3   Poderia ser melhor, pois não me doei o suficie...     Neutro       Neutro
# 4            Tive um desempenho razoavel na avaliação   Positivo       Neutro
# 5   O professor não mostrou uma completa dominio n...   Positivo     Negativo
# 6                De acordo com o professor eu fui bem   Positivo     Positivo
# 7   Me sinto frustrado com algumas materias por nã...     Neutro     Negativo
# 8                     Ocorreu de maneira satisfatoria   Positivo     Positivo
# 9   Aula bastante prudutiva, pois foi abordado div...   Positivo     Positivo
# 10  Diante das grandes dificudades, acredito que t...   Positivo     Positivo
# 11                            Muito bom o desempenho!   Positivo     Positivo
# 12  Hoje eu não prestei muita atençao no conteudo,...     Neutro     Negativo
# 13  Desempenho mediano, apresentado dificuldades s...   Negativo     Negativo
# 14  Gostei do meu desempenho, essa é uma materia q...   Positivo     Positivo
# 15  Eu acredito que fui bem na avaliação, pois me ...   Positivo     Positivo
# 16  Desempenho moderado, devido ao cansaço que é a...     Neutro       Neutro
# 17  Na avaliação de libras obtive um bom desempenh...   Positivo     Positivo
# 18  Achei que poderia ter sido melhor, mais pela f...     Neutro       Neutro
# 19  Fui otimo na avaliação de libras, minha dificu...   Positivo     Positivo
# 20  Nesta avaliação tive um otimo desempenho, apre...   Positivo     Positivo
# 21  Fui bem, estaria bem confiante quanto ao conteudo   Positivo     Positivo
# 22  Tenho muita coisa para melhorar, mais desde o ...     Neutro       Neutro
# 23                                   Não satisfatorio     Neutro     Negativo
# 24  Pela a avaliação ser de consulta, facilitou ba...   Positivo     Positivo
# 25                  Mediocre, poderia ter sido melhor     Neutro     Negativo
# 26  Eu acho que fui muito bem pois o professor me ...   Positivo     Positivo
# 27   Não estava preprado para realizar esta atividade     Neutro     Negativo
# 28                           Meu desempenho foi otimo   Positivo     Positivo
# 29  Por eu ter feito um estagio na area o assunto ...   Positivo     Positivo
# 30  Algoritmo e um da materias mais intensas do cu...     Neutro     Negativo
# 31  A avaliação aplicada estava de acordo com o co...   Positivo     Positivo
# 32  Foi uma avaliação que tratou de varios pontos ...   Positivo     Positivo
# 33  não fui dos melhores, faltou um pouco de conhe...     Neutro     Negativo
# 34        Bom desempenho, estudando fica melhor ainda     Neutro       Neutro
# 35                                     Bom desempenho   Positivo     Positivo
# 36  Neutro, prestando atenção fazendo pesquisas pa...   Positivo       Neutro
# 37  Não muito bem, esperava que seria diferente o ...     Neutro     Negativo
# 38  Decepcionada por não conseguir tirar uma nota boa     Neutro     Negativo
# 39  Eu perdi algumas aulas, estou um pouco receios...     Neutro       Neutro
# 40                        Meu desempenho e muito ruim     Neutro     Negativo
# 41                                   Não satisfatorio   Negativo     Negativo
# 42  Bem, o ato de conseguir evoluir a cada dia, em...   Positivo     Positivo
# 43  Desempenho bom, porem e necessario mudar e mel...   Positivo     Positivo
# 44  Achei muito bom meu desempenho, pois consegui ...   Positivo     Positivo
#
#    Sentimento
# 0     Score:0
# 1     Score:0
# 2     Score:0
# 3     Score:0
# 4     Score:0
# 5     Score:1
# 6     Score:0
# 7    Score:-1
# 8     Score:0
# 9     Score:0
# 10    Score:0
# 11    Score:1
# 12    Score:0
# 13    Score:0
# 14    Score:0
# 15    Score:0
# 16    Score:0
# 17    Score:1
# 18    Score:0
# 19    Score:0
# 20    Score:0
# 21    Score:1
# 22    Score:0
# 23    Score:0
# 24    Score:0
# 25    Score:0
# 26    Score:0
# 27    Score:0
# 28    Score:0
# 29    Score:0
# 30    Score:1
# 31    Score:0
# 32   Score:-1
# 33    Score:0
# 34    Score:1
# 35    Score:1
# 36    Score:0
# 37    Score:0
# 38    Score:0
# 39    Score:0
# 40   Score:-1
# 41    Score:0
# 42    Score:0
# 43    Score:0
# 44    Score:1

# %%
def predicao(anls):
    if anls >= 0.1:
        return 1.0
    elif (anls <= 0.1) and (anls >= -0.1):
        return 0.0
    else:
        return -1.0

# %%
def acuracia(anls, pred):
    if (anls - pred) == 0:
        return 1.0
    else:
        return 0.0
