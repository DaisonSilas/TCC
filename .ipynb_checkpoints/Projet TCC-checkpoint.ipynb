# %%
from textblob import TextBlob
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dados = pd.read_csv("Banco de dados melhorados.csv", delimiter=";")

# %%
def polaridade(pol):
    if pol == 'Positivo':
        return 1.0
    elif pol == 'Neutro':
        return 0.0
    else:
        return -1.0

# %%
polaridades = [polaridade(dados["Polaridade"][ind]) for ind in dados.index]

# %%
Nvpolaridades = [polaridade(dados["Nvpolaridade"][ind]) for ind in dados.index]

# %%
dados["Polaridade"] = polaridades

# %%
dados["Nvpolaridade"] = Nvpolaridades

# %%
def polaridade_textblob(text):
    frase = TextBlob (text)
    traduz = TextBlob(str(frase.translate(to="en" )))
    return traduz.polarity

# %%
polaridades = [polaridade_textblob(dados['Frase'][ind]) for ind in dados.index]

# %%
dados['Analise'] = polaridades

# %%
dados
# Out:
#                                                 Frase  Polaridade  \
# 0   Poderia ter sido melhor, devido ao pouco tempo...         1.0
# 1   Me sai bem na avaliação pois ele desenvolveu o...         1.0
# 2   Foi um desenvolvimento mediano, poderia ter um...         0.0
# 3   Poderia ser melhor, pois não me doei o suficie...         0.0
# 4            Tive um desempenho razoavel na avaliação         1.0
# 5   O professor não mostrou uma completa dominio n...         1.0
# 6                De acordo com o professor eu fui bem         1.0
# 7   Me sinto frustrado com algumas materias por nã...         0.0
# 8                     Ocorreu de maneira satisfatoria         1.0
# 9   Aula bastante prudutiva, pois foi abordado div...         1.0
# 10  Diante das grandes dificudades, acredito que t...         1.0
# 11                            Muito bom o desempenho!         1.0
# 12  Hoje eu não prestei muita atençao no conteudo,...         0.0
# 13  Desempenho mediano, apresentado dificuldades s...        -1.0
# 14  Gostei do meu desempenho, essa é uma materia q...         1.0
# 15  Eu acredito que fui bem na avaliação, pois me ...         1.0
# 16  Desempenho moderado, devido ao cansaço que é a...         0.0
# 17  Na avaliação de libras obtive um bom desempenh...         1.0
# 18  Achei que poderia ter sido melhor, mais pela f...         0.0
# 19  Fui otimo na avaliação de libras, minha dificu...         1.0
# 20  Nesta avaliação tive um otimo desempenho, apre...         1.0
# 21  Fui bem, estaria bem confiante quanto ao conteudo         1.0
# 22  Tenho muita coisa para melhorar, mais desde o ...         0.0
# 23                                   Não satisfatorio         0.0
# 24  Pela a avaliação ser de consulta, facilitou ba...         1.0
# 25                  Mediocre, poderia ter sido melhor         0.0
# 26  Eu acho que fui muito bem pois o professor me ...         1.0
# 27   Não estava preprado para realizar esta atividade         0.0
# 28                           Meu desempenho foi otimo         1.0
# 29  Por eu ter feito um estagio na area o assunto ...         1.0
# 30  Algoritmo e um da materias mais intensas do cu...         0.0
# 31  A avaliação aplicada estava de acordo com o co...         1.0
# 32  Foi uma avaliação que tratou de varios pontos ...         1.0
# 33  não fui dos melhores, faltou um pouco de conhe...         0.0
# 34        Bom desempenho, estudando fica melhor ainda         0.0
# 35                                     Bom desempenho         1.0
# 36  Neutro, prestando atenção fazendo pesquisas pa...         1.0
# 37  Não muito bem, esperava que seria diferente o ...         0.0
# 38  Decepcionada por não conseguir tirar uma nota boa         0.0
# 39  Eu perdi algumas aulas, estou um pouco receios...         0.0
# 40                        Meu desempenho e muito ruim         0.0
# 41                                   Não satisfatorio        -1.0
# 42  Bem, o ato de conseguir evoluir a cada dia, em...         1.0
# 43  Desempenho bom, porem e necessario mudar e mel...         1.0
# 44  Achei muito bom meu desempenho, pois consegui ...         1.0
#
#     Nvpolaridade   Analise
# 0            0.0  0.062500
# 1            1.0  0.100000
# 2            0.0  0.175000
# 3            0.0  0.250000
# 4            0.0  0.200000
# 5           -1.0 -0.051667
# 6            1.0  0.000000
# 7           -1.0 -0.700000
# 8            1.0  0.000000
# 9            1.0  0.100000
# 10           1.0  1.000000
# 11           1.0  1.000000
# 12          -1.0  0.093750
# 13          -1.0 -0.150000
# 14           1.0  0.288889
# 15           1.0  0.000000
# 16           0.0 -0.041667
# 17           1.0  0.550000
# 18           0.0  0.291667
# 19           1.0  0.660000
# 20           1.0  0.500000
# 21           1.0  0.650000
# 22           0.0  0.277778
# 23          -1.0  0.000000
# 24           1.0  0.000000
# 25          -1.0  0.000000
# 26           1.0  0.200000
# 27          -1.0  0.000000
# 28           1.0  0.800000
# 29           1.0  0.266667
# 30          -1.0 -0.084375
# 31           1.0  0.000000
# 32           1.0  0.150000
# 33          -1.0  0.406250
# 34           0.0  0.600000
# 35           1.0  0.700000
# 36           0.0  0.500000
# 37          -1.0 -0.066667
# 38          -1.0 -0.025000
# 39           0.0 -0.393750
# 40          -1.0 -0.910000
# 41          -1.0  0.000000
# 42           1.0  0.000000
# 43           1.0  0.233333
# 44           1.0  0.705000

# %%
def predicao(anls):
    if anls >= 0.1:
        return 1.0
    elif (anls <= 0.1) and (anls >= -0.1):
        return 0.0
    else:
        return -1.0

# %%
def acuracia(anls, pred):
    if (anls - pred) == 0:
        return 1.0
    else:
        return 0.0

# %%
predicao = [predicao(dados['Analise'][ind]) for ind in dados.index]

# %%
dados["Predicao"] = predicao

# %%
dados
# Out:
#                                                 Frase  Polaridade  \
# 0   Poderia ter sido melhor, devido ao pouco tempo...         1.0
# 1   Me sai bem na avaliação pois ele desenvolveu o...         1.0
# 2   Foi um desenvolvimento mediano, poderia ter um...         0.0
# 3   Poderia ser melhor, pois não me doei o suficie...         0.0
# 4            Tive um desempenho razoavel na avaliação         1.0
# 5   O professor não mostrou uma completa dominio n...         1.0
# 6                De acordo com o professor eu fui bem         1.0
# 7   Me sinto frustrado com algumas materias por nã...         0.0
# 8                     Ocorreu de maneira satisfatoria         1.0
# 9   Aula bastante prudutiva, pois foi abordado div...         1.0
# 10  Diante das grandes dificudades, acredito que t...         1.0
# 11                            Muito bom o desempenho!         1.0
# 12  Hoje eu não prestei muita atençao no conteudo,...         0.0
# 13  Desempenho mediano, apresentado dificuldades s...        -1.0
# 14  Gostei do meu desempenho, essa é uma materia q...         1.0
# 15  Eu acredito que fui bem na avaliação, pois me ...         1.0
# 16  Desempenho moderado, devido ao cansaço que é a...         0.0
# 17  Na avaliação de libras obtive um bom desempenh...         1.0
# 18  Achei que poderia ter sido melhor, mais pela f...         0.0
# 19  Fui otimo na avaliação de libras, minha dificu...         1.0
# 20  Nesta avaliação tive um otimo desempenho, apre...         1.0
# 21  Fui bem, estaria bem confiante quanto ao conteudo         1.0
# 22  Tenho muita coisa para melhorar, mais desde o ...         0.0
# 23                                   Não satisfatorio         0.0
# 24  Pela a avaliação ser de consulta, facilitou ba...         1.0
# 25                  Mediocre, poderia ter sido melhor         0.0
# 26  Eu acho que fui muito bem pois o professor me ...         1.0
# 27   Não estava preprado para realizar esta atividade         0.0
# 28                           Meu desempenho foi otimo         1.0
# 29  Por eu ter feito um estagio na area o assunto ...         1.0
# 30  Algoritmo e um da materias mais intensas do cu...         0.0
# 31  A avaliação aplicada estava de acordo com o co...         1.0
# 32  Foi uma avaliação que tratou de varios pontos ...         1.0
# 33  não fui dos melhores, faltou um pouco de conhe...         0.0
# 34        Bom desempenho, estudando fica melhor ainda         0.0
# 35                                     Bom desempenho         1.0
# 36  Neutro, prestando atenção fazendo pesquisas pa...         1.0
# 37  Não muito bem, esperava que seria diferente o ...         0.0
# 38  Decepcionada por não conseguir tirar uma nota boa         0.0
# 39  Eu perdi algumas aulas, estou um pouco receios...         0.0
# 40                        Meu desempenho e muito ruim         0.0
# 41                                   Não satisfatorio        -1.0
# 42  Bem, o ato de conseguir evoluir a cada dia, em...         1.0
# 43  Desempenho bom, porem e necessario mudar e mel...         1.0
# 44  Achei muito bom meu desempenho, pois consegui ...         1.0
#
#     Nvpolaridade   Analise  Predicao
# 0            0.0  0.062500       0.0
# 1            1.0  0.100000       1.0
# 2            0.0  0.175000       1.0
# 3            0.0  0.250000       1.0
# 4            0.0  0.200000       1.0
# 5           -1.0 -0.051667       0.0
# 6            1.0  0.000000       0.0
# 7           -1.0 -0.700000      -1.0
# 8            1.0  0.000000       0.0
# 9            1.0  0.100000       1.0
# 10           1.0  1.000000       1.0
# 11           1.0  1.000000       1.0
# 12          -1.0  0.093750       0.0
# 13          -1.0 -0.150000      -1.0
# 14           1.0  0.288889       1.0
# 15           1.0  0.000000       0.0
# 16           0.0 -0.041667       0.0
# 17           1.0  0.550000       1.0
# 18           0.0  0.291667       1.0
# 19           1.0  0.660000       1.0
# 20           1.0  0.500000       1.0
# 21           1.0  0.650000       1.0
# 22           0.0  0.277778       1.0
# 23          -1.0  0.000000       0.0
# 24           1.0  0.000000       0.0
# 25          -1.0  0.000000       0.0
# 26           1.0  0.200000       1.0
# 27          -1.0  0.000000       0.0
# 28           1.0  0.800000       1.0
# 29           1.0  0.266667       1.0
# 30          -1.0 -0.084375       0.0
# 31           1.0  0.000000       0.0
# 32           1.0  0.150000       1.0
# 33          -1.0  0.406250       1.0
# 34           0.0  0.600000       1.0
# 35           1.0  0.700000       1.0
# 36           0.0  0.500000       1.0
# 37          -1.0 -0.066667       0.0
# 38          -1.0 -0.025000       0.0
# 39           0.0 -0.393750      -1.0
# 40          -1.0 -0.910000      -1.0
# 41          -1.0  0.000000       0.0
# 42           1.0  0.000000       0.0
# 43           1.0  0.233333       1.0
# 44           1.0  0.705000       1.0

# %%
acuracia = [acuracia(dados['Polaridade'][ind], dados['Predicao'][ind]) for ind in dados.index]

# %%
dados["Acuracia"] = acuracia

# %%
dados["Acuracia"].value_counts()
# Out:
# 1.0    27
# 0.0    18
# Name: Acuracia, dtype: int64

# %%
dados.hist(column='Analise', bins=10)
plt.show()
